# %%
import pandas as pd 
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in c:\users\hp\anaconda3\lib\site-packages (1.1.2)

# %%
df=pd.read_csv('GroceryStoreDataSet.csv')

# %%
df
# Out:
#     coffee   donut   sugar   bread    soup
# 0     soda   candy    milk  cheese     NaN
# 1    fruit   bread   cream     NaN     NaN
# 2   coffee   donut     NaN     NaN     NaN
# 3    water    soup    milk     NaN     NaN
# 4     soda   candy     NaN     NaN     NaN
# ..     ...     ...     ...     ...     ...
# 94    milk     NaN     NaN     NaN     NaN
# 95    soda   candy     NaN     NaN     NaN
# 96   donut   water  cheese   cream  coffee
# 97     jam    cake   bread     NaN     NaN
# 98   cream  coffee   suger   donut     NaN
#
# [99 rows x 5 columns]

# %%
data=[]
for i in range(0,len(df)):
    data.append([str(df.values[i,j])for j in range(0,5)])

# %%
data
# Out:
# [['soda', 'candy', 'milk', 'cheese', 'nan'],
#  ['fruit', 'bread', 'cream', 'nan', 'nan'],
#  ['coffee', 'donut', 'nan', 'nan', 'nan'],
#  ['water', 'soup', 'milk', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['coffee', 'sugar', 'donut', 'cheese', 'soda'],
#  ['water', 'bread', 'cream', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['coffee', 'cream', 'cheese', 'soup', 'soda'],
#  ['water', 'cake', 'cream', 'soda', 'nan'],
#  ['soda', 'cake', 'milk', 'candy', 'nan'],
#  ['coffee', 'sugar', 'donut', 'nan', 'nan'],
#  ['fruit', 'cream', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'cheese', 'nan', 'nan'],
#  ['water', 'bread', 'nan', 'nan', 'nan'],
#  ['coffee', 'cream', 'sugar', 'soda', 'nan'],
#  ['water', 'bread', 'soup', 'nan', 'nan'],
#  ['soda', 'candy', 'milk', 'nan', 'nan'],
#  ['soda', 'candy', 'cheese', 'nan', 'nan'],
#  ['coffee', 'cream', 'donut', 'nan', 'nan'],
#  ['soda', 'bread', 'nuts', 'nan', 'nan'],
#  ['soda', 'cake', 'soup', 'candy', 'nan'],
#  ['jam', 'cake', 'bread', 'nan', 'nan'],
#  ['coffee', 'donut', 'nan', 'nan', 'nan'],
#  ['jam', 'cheese', 'bread', 'soda', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['soda', 'cake', 'milk', 'cheese', 'bread'],
#  ['soda', 'cake', 'soup', 'nan', 'nan'],
#  ['water', 'cake', 'nan', 'nan', 'nan'],
#  ['coffee', 'donut', 'bread', 'soda', 'nan'],
#  ['milk', 'cream', 'nan', 'nan', 'nan'],
#  ['soda', 'milk', 'candy', 'nan', 'nan'],
#  ['milk', 'cake', 'nan', 'nan', 'nan'],
#  ['coffee', 'sugar', 'soup', 'donut', 'nan'],
#  ['bread', 'cheese', 'jam', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['bread', 'cake', 'jam', 'nan', 'nan'],
#  ['bread', 'milk', 'water', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['soda', 'cream', 'bread', 'nan', 'nan'],
#  ['water', 'cheese', 'nan', 'nan', 'nan'],
#  ['coffee', 'soup', 'donut', 'nan', 'nan'],
#  ['jam', 'water', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['donut', 'milk', 'bread', 'coffee', 'nan'],
#  ['fruit', 'cake', 'nan', 'nan', 'nan'],
#  ['jam', 'soda', 'soup', 'nan', 'nan'],
#  ['sugar', 'coffee', 'nan', 'nan', 'nan'],
#  ['cream', 'sugar', 'nan', 'nan', 'nan'],
#  ['soda', 'cheese', 'candy', 'nan', 'nan'],
#  ['sugar', 'milk', 'nan', 'nan', 'nan'],
#  ['coffee', 'soda', 'sugar', 'donut', 'nan'],
#  ['milk', 'cake', 'nan', 'nan', 'nan'],
#  ['water', 'bread', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'soup', 'nan', 'nan'],
#  ['soda', 'bread', 'candy', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['coffee', 'soup', 'donut', 'nan', 'nan'],
#  ['donut', 'cheese', 'soda', 'nan', 'nan'],
#  ['water', 'milk', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['nuts', 'soup', 'soda', 'nan', 'nan'],
#  ['fruit', 'milk', 'nan', 'nan', 'nan'],
#  ['nuts', 'water', 'nan', 'nan', 'nan'],
#  ['coffee', 'cheese', 'donut', 'nan', 'nan'],
#  ['nuts', 'cake', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['sugar', 'candy', 'soup', 'nan', 'nan'],
#  ['coffee', 'sugar', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['jam', 'bread', 'cream', 'nan', 'nan'],
#  ['coffee', 'donut', 'milk', 'cake', 'nan'],
#  ['nuts', 'water', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['nuts', 'water', 'candy', 'nan', 'nan'],
#  ['water', 'soup', 'nan', 'nan', 'nan'],
#  ['coffee', 'donut', 'sugar', 'nan', 'nan'],
#  ['nuts', 'cheese', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'milk', 'nan', 'nan'],
#  ['jam', 'bread', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['coffee', 'cream', 'cake', 'nan', 'nan'],
#  ['donut', 'water', 'coffee', 'nan', 'nan'],
#  ['soda', 'cream', 'candy', 'nan', 'nan'],
#  ['jam', 'bread', 'milk', 'nan', 'nan'],
#  ['coffee', 'donut', 'cheese', 'nan', 'nan'],
#  ['nuts', 'nan', 'nan', 'nan', 'nan'],
#  ['soda', 'water', 'cake', 'nan', 'nan'],
#  ['fruit', 'soup', 'nan', 'nan', 'nan'],
#  ['water', 'nan', 'nan', 'nan', 'nan'],
#  ['coffee', 'donut', 'nan', 'nan', 'nan'],
#  ['milk', 'nan', 'nan', 'nan', 'nan'],
#  ['soda', 'candy', 'nan', 'nan', 'nan'],
#  ['donut', 'water', 'cheese', 'cream', 'coffee'],
#  ['jam', 'cake', 'bread', 'nan', 'nan'],
#  ['cream', 'coffee', 'suger', 'donut', 'nan']]

# %%
from apyori import apriori

# Training Apriori on the dataset
rules = apriori(data, min_support = 0.08, min_confidence = 0.7, min_lift = 3, min_length = 2,
               max_length = 3)

# Create list of results
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'bread', 'jam'}), support=0.08080808080808081, ordered_statistics=[OrderedStatistic(items_base=frozenset({'jam'}), items_add=frozenset({'bread'}), confidence=0.8, lift=3.9600000000000004)]),
#  RelationRecord(items=frozenset({'coffee', 'donut'}), support=0.1919191919191919, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee'}), items_add=frozenset({'donut'}), confidence=0.7916666666666666, lift=3.9187499999999997), OrderedStatistic(items_base=frozenset({'donut'}), items_add=frozenset({'coffee'}), confidence=0.95, lift=3.9187499999999997)]),
#  RelationRecord(items=frozenset({'coffee', 'sugar'}), support=0.08080808080808081, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sugar'}), items_add=frozenset({'coffee'}), confidence=0.7272727272727274, lift=3.0000000000000004)]),
#  RelationRecord(items=frozenset({'bread', 'nan', 'jam'}), support=0.08080808080808081, ordered_statistics=[OrderedStatistic(items_base=frozenset({'jam'}), items_add=frozenset({'bread', 'nan'}), confidence=0.8, lift=4.1684210526315795), OrderedStatistic(items_base=frozenset({'nan', 'jam'}), items_add=frozenset({'bread'}), confidence=0.8, lift=3.9600000000000004)]),
#  RelationRecord(items=frozenset({'coffee', 'nan', 'donut'}), support=0.1717171717171717, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee'}), items_add=frozenset({'nan', 'donut'}), confidence=0.7083333333333333, lift=3.895833333333333), OrderedStatistic(items_base=frozenset({'donut'}), items_add=frozenset({'coffee', 'nan'}), confidence=0.85, lift=4.007142857142857), OrderedStatistic(items_base=frozenset({'coffee', 'nan'}), items_add=frozenset({'donut'}), confidence=0.8095238095238095, lift=4.007142857142857), OrderedStatistic(items_base=frozenset({'nan', 'donut'}), items_add=frozenset({'coffee'}), confidence=0.9444444444444444, lift=3.895833333333333)])]

# %%
def inspect(results):
    li          = [tuple(result[2][0][0])[0] for result in results]
    ri          = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(li, ri, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Item', 'Right Item', 'Support', 'Confidence', 'Lift'])

# %%
resultsinDataFrame
# Out:
#   Left Item Right Item   Support  Confidence      Lift
# 0       jam      bread  0.080808    0.800000  3.960000
# 1    coffee      donut  0.191919    0.791667  3.918750
# 2     sugar     coffee  0.080808    0.727273  3.000000
# 3       jam      bread  0.080808    0.800000  4.168421
# 4    coffee        nan  0.171717    0.708333  3.895833
